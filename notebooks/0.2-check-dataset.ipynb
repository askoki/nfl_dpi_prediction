# %%
import pandas as pd

# %%
play_df = pd.read_csv("data/plays.csv")

# %%
week_1_df = pd.read_csv("data/week1.csv")

# %%
games_df = pd.read_csv("data/games.csv")

# %%
week_1_df.shape
# Out:
# (986022, 19)

# %%
play_df.columns
# Out:
# Index(['gameId', 'playId', 'playDescription', 'quarter', 'down', 'yardsToGo',
#        'possessionTeam', 'playType', 'yardlineSide', 'yardlineNumber',
#        'offenseFormation', 'personnelO', 'defendersInTheBox',
#        'numberOfPassRushers', 'personnelD', 'typeDropback',
#        'preSnapVisitorScore', 'preSnapHomeScore', 'gameClock',
#        'absoluteYardlineNumber', 'penaltyCodes', 'penaltyJerseyNumbers',
#        'passResult', 'offensePlayResult', 'playResult', 'epa',
#        'isDefensivePI'],
#       dtype='object')

# %%
# find DPI (defensive pass interference) and which game and play id
dpi_example = play_df[play_df.penaltyCodes == 'DPI'].iloc[0]

# %%
dpi_example
# Out:
# gameId                                                           2018092700
# playId                                                                 1268
# playDescription           (8:13) K.Cousins pass deep right to A.Robinson...
# quarter                                                                   2
# down                                                                      1
# yardsToGo                                                                10
# possessionTeam                                                          MIN
# playType                                                     play_type_pass
# yardlineSide                                                             LA
# yardlineNumber                                                           17
# offenseFormation                                                 SINGLEBACK
# personnelO                                                 1 RB, 2 TE, 2 WR
# ...

# %%
play_df[play_df.penaltyCodes == 'DPI'].playType.value_counts()
# Out:
# play_type_unknown    221
# play_type_pass        21
# Name: playType, dtype: int64

# %%
games_df.columns
# Out:
# Index(['gameId', 'gameDate', 'gameTimeEastern', 'homeTeamAbbr',
#        'visitorTeamAbbr', 'week'],
#       dtype='object')

# %%
games_df.shape
# Out:
# (253, 6)

# %%
game_example = games_df[games_df.gameId == 2018092700]
game_example
# Out:
#         gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 45  2018092700  09/27/2018        20:20:00           LA             MIN     4

# %%
week_4_df = pd.read_csv("data/week4.csv")

# %%
match_data_example_dpi = week_4_df[week_4_df.playId == 1268]
match_data_example_dpi
# Out:
#                            time      x      y     s     a   dis       o  \
# 28669  2018-09-28T01:10:36.500Z  26.05  12.31  0.13  0.04  0.02   88.95
# 28670  2018-09-28T01:10:36.500Z  28.13  12.22  0.01  0.01  0.01  288.94
# 28671  2018-09-28T01:10:36.500Z  27.85  29.66  0.00  0.00  0.00  269.47
# 28672  2018-09-28T01:10:36.500Z  28.46  23.68  0.00  0.00  0.00  253.11
# 28673  2018-09-28T01:10:36.500Z  29.54  32.16  0.01  0.01  0.01  252.05
# ...                         ...    ...    ...   ...   ...   ...     ...
# 29729  2018-09-28T01:10:43.500Z  27.30  15.53  3.45  0.61  0.34  326.23
# 29730  2018-09-28T01:10:43.500Z   4.04  44.85  7.91  1.91  0.80  348.50
# 29731  2018-09-28T01:10:43.500Z  34.00  44.29  2.90  2.04  0.30  321.07
# 29732  2018-09-28T01:10:43.500Z  19.19  43.83  4.90  1.33  0.50  320.44
# 29733  2018-09-28T01:10:43.500Z   2.08  43.82  6.46  1.14  0.65     NaN
#
#           dir event      nflId       displayName  jerseyNumber position  \
# ...

# %%
match_data_example_dpi.shape
# Out:
# (1065, 19)

# %%
match_data_example_dpi = match_data_example_dpi.sort_values(by='frameId')
match_data_example_dpi[:16]
# Out:
#                            time      x      y     s     a   dis       o  \
# 28669  2018-09-28T01:10:36.500Z  26.05  12.31  0.13  0.04  0.02   88.95
# 28672  2018-09-28T01:10:36.500Z  28.46  23.68  0.00  0.00  0.00  253.11
# 28673  2018-09-28T01:10:36.500Z  29.54  32.16  0.01  0.01  0.01  252.05
# 28676  2018-09-28T01:10:36.500Z  19.99  33.31  0.40  0.25  0.04  102.99
# 28670  2018-09-28T01:10:36.500Z  28.13  12.22  0.01  0.01  0.01  288.94
# 28674  2018-09-28T01:10:36.500Z  20.22  20.99  3.65  2.48  0.38  123.57
# 28675  2018-09-28T01:10:36.500Z  23.50  22.80  0.01  0.01  0.01   87.02
# 28671  2018-09-28T01:10:36.500Z  27.85  29.66  0.00  0.00  0.00  269.47
# 28677  2018-09-28T01:10:36.500Z  25.65  18.22  0.33  0.89  0.03   78.90
# 28678  2018-09-28T01:10:36.500Z  24.59  27.91  0.04  0.04  0.01   96.14
# 28682  2018-09-28T01:10:36.500Z  29.50  17.37  1.87  5.24  0.20  285.19
# 28683  2018-09-28T01:10:36.500Z  26.83  23.77  0.00  0.00  0.00     NaN
# ...
