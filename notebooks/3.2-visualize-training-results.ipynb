# %%
from sklearn.metrics import accuracy_score
import os
import sys
sys.path.append("../")
import numpy as np
from datetime import datetime
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from settings import PROCESSED_DATA_DIR, MODELS_DIR
from src.features.helpers.training import make_lstm_model, get_early_stopping_definition, plot_training_validation_loss


ML_MODEL = 'test_visualisation'

print(f'{datetime.now().strftime("%H:%M:%S")} Start data loading...')
x_train = np.load(os.path.join(PROCESSED_DATA_DIR, 'x_train.npy'), allow_pickle=True)
y_train = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_train.npy'), allow_pickle=True)

x_val = np.load(os.path.join(PROCESSED_DATA_DIR, 'x_val.npy'), allow_pickle=True)
y_val = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_val.npy'), allow_pickle=True)

x_test = np.load(os.path.join(PROCESSED_DATA_DIR, 'x_test.npy'), allow_pickle=True)
y_test = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_test.npy'), allow_pickle=True)

print(f'{datetime.now().strftime("%H:%M:%S")} End data loading...')

# num_positives = y_train_num.count(1)
num_positives = np.count_nonzero(y_train == 1)

# num_negatives = y_train.count(0)
num_negatives = np.count_nonzero(y_train == 0)

total = len(y_train)

print(
    f'Examples:\n    Total: {total}\n    Positive: {num_positives} ({round(100 * num_positives / total, 2)}% of total)\n')

# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_0 = 1
weight_for_1 = int(num_negatives / num_positives) if num_positives != 0 else 0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))

initial_bias = np.log([num_positives / num_negatives])

# ### Input is sensitive (make sure that big numbers are not causing loss issue (could be gameIdplayId column))
# ### https://stackoverflow.com/questions/37232782/nan-loss-when-training-regression-network

EPOCHS = 20
BATCH_SIZE = 32
model = KerasClassifier(
    build_fn=make_lstm_model,
    input_dim=(x_train.shape[1], x_train.shape[2]),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1
)

print(f'{datetime.now().strftime("%H:%M:%S")} Start training...')

history = model.fit(
    x_train,
    y_train,
    class_weight=class_weight,
    validation_data=(x_val, y_val),
    callbacks=[get_early_stopping_definition(mode='min')]
)

print(f'{datetime.now().strftime("%H:%M:%S")} End training...')
model.model.summary()

print("Saving model...")
model.model.save(os.path.join(MODELS_DIR, f"{ML_MODEL}_rnn.h5"))
# Out:
# 09:19:38 Start data loading...
# 09:19:38 End data loading...
# Examples:
#     Total: 11
#     Positive: 0 (0.0% of total)
#
# Weight for class 0: 1.00
# Weight for class 1: 0.00
# 09:19:38 Start training...
# <ipython-input-2-ffe823832a04>:47: RuntimeWarning: divide by zero encountered in log
#   initial_bias = np.log([num_positives / num_negatives])
# Epoch 1/20
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00WARNING:tensorflow:Model was constructed with shape (None, 84, 178) for input Tensor("masking_input:0", shape=(None, 84, 178), dtype=float32), but it was called on an input with incompatible shape (None, 88, 178).
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00Restoring model weights from the end of the best epoch.
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 00004: early stopping
# 09:19:55 End training...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 84, 178)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 84, 256)           314368
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               394240
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 708,865
# Trainable params: 708,865
# Non-trainable params: 0
# _________________________________________________________________
# Saving model...

# %%
x = x_train[:50]
orig_out = model.model.predict(x)

# %%
orig_out.shape
# Out:
# (11, 1)

# %%
x_train[0].shape[1]
# Out:
# 178

# %%
for i in range(x_train[0].shape[1]):  # iterate over the three features
    new_x = x.copy()
    perturbation = np.random.normal(0.0, 0.2, size=new_x.shape[:2])
    new_x[:, :, i] = new_x[:, :, i] + perturbation
    perturbed_out = model.model.predict(new_x)
    effect = ((orig_out - perturbed_out) ** 2).mean() ** 0.5
    print(f'Variable {i+1}, perturbation effect: {effect:.4f}')
# Out:
# Variable 1, perturbation effect: 0.0321
# Variable 2, perturbation effect: 0.0321
# Variable 3, perturbation effect: 0.0318
# Variable 4, perturbation effect: 0.0320
# Variable 5, perturbation effect: 0.0321
# Variable 6, perturbation effect: 0.0321
# Variable 7, perturbation effect: 0.0320
# Variable 8, perturbation effect: 0.0318
# Variable 9, perturbation effect: 0.0319
# Variable 10, perturbation effect: 0.0319
# Variable 11, perturbation effect: 0.0320
# Variable 12, perturbation effect: 0.0319
# Variable 13, perturbation effect: 0.0320
# Variable 14, perturbation effect: 0.0319
# Variable 15, perturbation effect: 0.0320
# Variable 16, perturbation effect: 0.0319
# Variable 17, perturbation effect: 0.0317
# Variable 18, perturbation effect: 0.0316
# Variable 19, perturbation effect: 0.0319
# Variable 20, perturbation effect: 0.0316
# Variable 21, perturbation effect: 0.0319
# Variable 22, perturbation effect: 0.0319
# Variable 23, perturbation effect: 0.0323
# Variable 24, perturbation effect: 0.0320
# Variable 25, perturbation effect: 0.0323
# Variable 26, perturbation effect: 0.0321
# Variable 27, perturbation effect: 0.0318
# Variable 28, perturbation effect: 0.0316
# Variable 29, perturbation effect: 0.0320
# Variable 30, perturbation effect: 0.0320
# Variable 31, perturbation effect: 0.0320
# Variable 32, perturbation effect: 0.0321
# Variable 33, perturbation effect: 0.0321
# Variable 34, perturbation effect: 0.0322
# Variable 35, perturbation effect: 0.0321
# Variable 36, perturbation effect: 0.0319
# Variable 37, perturbation effect: 0.0323
# Variable 38, perturbation effect: 0.0317
# Variable 39, perturbation effect: 0.0323
# Variable 40, perturbation effect: 0.0320
# Variable 41, perturbation effect: 0.0322
# Variable 42, perturbation effect: 0.0320
# Variable 43, perturbation effect: 0.0320
# Variable 44, perturbation effect: 0.0320
# Variable 45, perturbation effect: 0.0321
# Variable 46, perturbation effect: 0.0319
# Variable 47, perturbation effect: 0.0321
# Variable 48, perturbation effect: 0.0321
# Variable 49, perturbation effect: 0.0320
# Variable 50, perturbation effect: 0.0321
# Variable 51, perturbation effect: 0.0321
# Variable 52, perturbation effect: 0.0321
# Variable 53, perturbation effect: 0.0320
# Variable 54, perturbation effect: 0.0320
# Variable 55, perturbation effect: 0.0319
# Variable 56, perturbation effect: 0.0319
# Variable 57, perturbation effect: 0.0319
# Variable 58, perturbation effect: 0.0318
# Variable 59, perturbation effect: 0.0319
# Variable 60, perturbation effect: 0.0318
# Variable 61, perturbation effect: 0.0320
# Variable 62, perturbation effect: 0.0321
# Variable 63, perturbation effect: 0.0318
# Variable 64, perturbation effect: 0.0326
# Variable 65, perturbation effect: 0.0319
# Variable 66, perturbation effect: 0.0320
# Variable 67, perturbation effect: 0.0321
# Variable 68, perturbation effect: 0.0325
# Variable 69, perturbation effect: 0.0322
# Variable 70, perturbation effect: 0.0320
# Variable 71, perturbation effect: 0.0318
# Variable 72, perturbation effect: 0.0317
# Variable 73, perturbation effect: 0.0320
# Variable 74, perturbation effect: 0.0319
# Variable 75, perturbation effect: 0.0317
# Variable 76, perturbation effect: 0.0318
# Variable 77, perturbation effect: 0.0318
# Variable 78, perturbation effect: 0.0321
# Variable 79, perturbation effect: 0.0320
# Variable 80, perturbation effect: 0.0324
# Variable 81, perturbation effect: 0.0319
# Variable 82, perturbation effect: 0.0318
# Variable 83, perturbation effect: 0.0322
# Variable 84, perturbation effect: 0.0323
# Variable 85, perturbation effect: 0.0317
# Variable 86, perturbation effect: 0.0320
# Variable 87, perturbation effect: 0.0318
# Variable 88, perturbation effect: 0.0319
# Variable 89, perturbation effect: 0.0319
# Variable 90, perturbation effect: 0.0322
# Variable 91, perturbation effect: 0.0321
# Variable 92, perturbation effect: 0.0320
# Variable 93, perturbation effect: 0.0321
# Variable 94, perturbation effect: 0.0320
# Variable 95, perturbation effect: 0.0318
# Variable 96, perturbation effect: 0.0320
# Variable 97, perturbation effect: 0.0322
# Variable 98, perturbation effect: 0.0319
# Variable 99, perturbation effect: 0.0328
# Variable 100, perturbation effect: 0.0321
# Variable 101, perturbation effect: 0.0319
# Variable 102, perturbation effect: 0.0319
# Variable 103, perturbation effect: 0.0322
# Variable 104, perturbation effect: 0.0319
# Variable 105, perturbation effect: 0.0321
# Variable 106, perturbation effect: 0.0320
# Variable 107, perturbation effect: 0.0322
# Variable 108, perturbation effect: 0.0318
# Variable 109, perturbation effect: 0.0319
# Variable 110, perturbation effect: 0.0319
# Variable 111, perturbation effect: 0.0319
# Variable 112, perturbation effect: 0.0318
# Variable 113, perturbation effect: 0.0318
# Variable 114, perturbation effect: 0.0320
# Variable 115, perturbation effect: 0.0322
# Variable 116, perturbation effect: 0.0322
# Variable 117, perturbation effect: 0.0318
# Variable 118, perturbation effect: 0.0329
# Variable 119, perturbation effect: 0.0321
# Variable 120, perturbation effect: 0.0322
# Variable 121, perturbation effect: 0.0320
# Variable 122, perturbation effect: 0.0319
# Variable 123, perturbation effect: 0.0320
# Variable 124, perturbation effect: 0.0319
# Variable 125, perturbation effect: 0.0318
# Variable 126, perturbation effect: 0.0319
# Variable 127, perturbation effect: 0.0322
# Variable 128, perturbation effect: 0.0318
# Variable 129, perturbation effect: 0.0320
# Variable 130, perturbation effect: 0.0322
# Variable 131, perturbation effect: 0.0321
# Variable 132, perturbation effect: 0.0320
# Variable 133, perturbation effect: 0.0316
# Variable 134, perturbation effect: 0.0320
# Variable 135, perturbation effect: 0.0318
# Variable 136, perturbation effect: 0.0319
# Variable 137, perturbation effect: 0.0322
# Variable 138, perturbation effect: 0.0319
# Variable 139, perturbation effect: 0.0318
# Variable 140, perturbation effect: 0.0321
# Variable 141, perturbation effect: 0.0321
# Variable 142, perturbation effect: 0.0320
# Variable 143, perturbation effect: 0.0318
# Variable 144, perturbation effect: 0.0322
# Variable 145, perturbation effect: 0.0322
# Variable 146, perturbation effect: 0.0319
# Variable 147, perturbation effect: 0.0319
# Variable 148, perturbation effect: 0.0323
# Variable 149, perturbation effect: 0.0320
# Variable 150, perturbation effect: 0.0321
# Variable 151, perturbation effect: 0.0319
# Variable 152, perturbation effect: 0.0320
# Variable 153, perturbation effect: 0.0323
# Variable 154, perturbation effect: 0.0323
# Variable 155, perturbation effect: 0.0317
# Variable 156, perturbation effect: 0.0316
# Variable 157, perturbation effect: 0.0317
# Variable 158, perturbation effect: 0.0319
# Variable 159, perturbation effect: 0.0321
# Variable 160, perturbation effect: 0.0319
# Variable 161, perturbation effect: 0.0317
# Variable 162, perturbation effect: 0.0321
# Variable 163, perturbation effect: 0.0321
# Variable 164, perturbation effect: 0.0319
# Variable 165, perturbation effect: 0.0320
# Variable 166, perturbation effect: 0.0319
# Variable 167, perturbation effect: 0.0319
# Variable 168, perturbation effect: 0.0320
# Variable 169, perturbation effect: 0.0321
# Variable 170, perturbation effect: 0.0319
# Variable 171, perturbation effect: 0.0319
# Variable 172, perturbation effect: 0.0319
# Variable 173, perturbation effect: 0.0320
# Variable 174, perturbation effect: 0.0321
# Variable 175, perturbation effect: 0.0318
# Variable 176, perturbation effect: 0.0318
# Variable 177, perturbation effect: 0.0322
# Variable 178, perturbation effect: 0.0319

# %% [markdown]
# ## Conclusion: no feature is important enough -> this needs to be tested on real model
