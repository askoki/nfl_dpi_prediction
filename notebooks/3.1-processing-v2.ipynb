# %%
import sys
sys.path.append("../")
from settings import RAW_DATA_DIR
import pandas as pd
import plotly.express as px
import os
import numpy as np

# %%
play_df = pd.read_csv(os.path.join(RAW_DATA_DIR, 'plays.csv'))
games_df = pd.read_csv(os.path.join(RAW_DATA_DIR, 'games.csv'))

# %%
week_and_games = games_df[games_df.week == 1]
tracking_df = pd.read_csv(os.path.join(RAW_DATA_DIR, f'week{1}.csv'))

# %%
games_n_plays_df = play_df.merge(week_and_games, how='inner', on='gameId')

# %%
from src.features.helpers.processing import add_missing_timestamp_values

# %%
tracking_df = add_missing_timestamp_values(tracking_df)
# Out:
# Start record processing. Differentiate timestamps that have multiple records...
# Time: 16:52:39
# End record processing: 16:54:43

# %%
df_t = tracking_df.merge(games_n_plays_df, how='left', on=['gameId', 'playId'])

# %%
df_t.columns
# Out:
# Index(['time', 'x', 'y', 's', 'a', 'dis', 'o', 'dir', 'event', 'nflId',
#        'displayName', 'jerseyNumber', 'position', 'frameId', 'team', 'gameId',
#        'playId', 'playDirection', 'route', 'playDescription', 'quarter',
#        'down', 'yardsToGo', 'possessionTeam', 'playType', 'yardlineSide',
#        'yardlineNumber', 'offenseFormation', 'personnelO', 'defendersInTheBox',
#        'numberOfPassRushers', 'personnelD', 'typeDropback',
#        'preSnapVisitorScore', 'preSnapHomeScore', 'gameClock',
#        'absoluteYardlineNumber', 'penaltyCodes', 'penaltyJerseyNumbers',
#        'passResult', 'offensePlayResult', 'playResult', 'epa', 'isDefensivePI',
#        'gameDate', 'gameTimeEastern', 'homeTeamAbbr', 'visitorTeamAbbr',
#        'week'],
#       dtype='object')

# %%
df_t.shape
# Out:
# (986022, 49)

# %%
gb = df_t.groupby(['gameId', 'playId'])
len(gb)
# Out:
# 1034

# %%
df_c = df_t.copy()
df_c.shape
# Out:
# (986022, 49)

# %%
for name, group in gb:
    game_id, play_id = name
    
    # if group does not contain pass forward, drop it
    if all(group.event != 'pass_forward'):
        df_c = df_c[(df_c.gameId != game_id) | (df_c.playId != play_id)]
df_c.shape
# Out:
# (918456, 49)

# %%
gb_2 = df_c.groupby(['gameId', 'playId'])

# %%
df_d = df_c.copy().sort_index()
df_d.shape
# Out:
# (918456, 49)

# %%
max_groups = len(gb_2)
delete_list = []
for i, data in enumerate(gb_2):
    #print(f'Processing {i}/{max_groups}')
    name, group = data
    game_id, play_id = name
    
    drop_end = group[group.event == 'pass_forward'].head(1).index[0]
    delete_list = group[group.index < drop_end].index.to_list()
    df_d = df_d.drop(delete_list)
df_d.shape
# Out:
# (388245, 49)

# %%
df_d.event.value_counts()
# Out:
# None                         332813
# pass_forward                  14166
# pass_arrived                  11410
# pass_outcome_caught            8133
# tackle                         6567
# first_contact                  6457
# pass_outcome_incomplete        5291
# out_of_bounds                  1728
# pass_outcome_interception       485
# touchdown                       352
# pass_tipped                     280
# pass_outcome_touchdown          214
# fumble                          143
# fumble_defense_recovered        100
# fumble_offense_recovered         44
# penalty_flag                     32
# touchback                        30
# Name: event, dtype: int64

# %%
df_d.penaltyJerseyNumbers.value_counts()
# Out:
# CLE 95                  1517
# BUF 13                  1458
# MIA 97;TEN 33;MIA 28    1232
# LA 41                   1065
# ARI 28                   967
#                         ...
# TB 58                    165
# CIN 22                   154
# CLE 69                   144
# CLE 80                   144
# IND 11                   140
# Name: penaltyJerseyNumbers, Length: 66, dtype: int64

# %%
def animated_slice(df):
    fig = px.scatter(
        df, 
        x='x', y='y', color='team', text='position', animation_frame='time', animation_group='displayName',
        range_x=[-10, 130], range_y=[-10, 60],
        hover_data=['displayName', 'jerseyNumber', 's', 'a', 'dis', 'o', 'dir', 'playDirection'])
    fig.update_traces(textposition='top center', marker_size=10)
    # , transition = {'duration': 500}
    fig.update_layout(paper_bgcolor='darkgreen', plot_bgcolor='darkgreen', font_color='white')
    
    return fig

# %%
df_cd = df_d.sort_values('time').reset_index(drop=True)
df_cd.head(30)
# Out:
#                         time      x      y      s     a   dis       o     dir  \
# 0   2018-09-07T01:07:18.099Z  96.43  26.78   0.84  2.05  0.08  356.40  333.39
# 1   2018-09-07T01:07:18.099Z  96.90  26.97   2.05  3.76  0.22     NaN     NaN
# 2   2018-09-07T01:07:18.099Z  89.62  18.39   6.75  1.51  0.67  197.78  208.19
# 3   2018-09-07T01:07:18.099Z  83.06  25.98   4.08  3.73  0.40   42.57  303.26
# 4   2018-09-07T01:07:18.099Z  83.20  21.36   6.21  2.68  0.62  262.52  260.44
# 5   2018-09-07T01:07:18.099Z  79.51  20.00   2.99  0.69  0.30   78.25  259.75
# 6   2018-09-07T01:07:18.099Z  86.10  33.53   3.75  1.49  0.37   52.23  311.29
# 7   2018-09-07T01:07:18.099Z  76.53  44.93   4.68  2.18  0.47  182.14  277.48
# 8   2018-09-07T01:07:18.099Z  69.63  30.81   2.93  2.65  0.30   79.24  315.98
# 9   2018-09-07T01:07:18.099Z  82.65  34.56   6.35  1.21  0.64  262.06  272.78
# 10  2018-09-07T01:07:18.099Z  86.02  18.64   3.52  0.69  0.35   28.19  216.15
# 11  2018-09-07T01:07:18.099Z  80.69  44.91   3.11  6.67  0.34  155.11  297.88
# 12  2018-09-07T01:07:18.099Z  84.82  38.33   5.53  4.30  0.54  295.34  318.58
# 13  2018-09-07T01:07:18.099Z  93.81  27.30   3.92  3.23  0.39  293.03  332.35
# 14  2018-09-07T01:07:18.200Z  79.22  19.94   3.05  0.69  0.30   81.94  257.84
# 15  2018-09-07T01:07:18.200Z  97.09  26.98   1.74  3.24  0.19     NaN     NaN
# 16  2018-09-07T01:07:18.200Z  89.31  17.77   6.95  1.77  0.70  183.54  205.97
# 17  2018-09-07T01:07:18.200Z  82.71  26.24   4.43  3.72  0.43   26.13  308.53
# 18  2018-09-07T01:07:18.200Z  76.08  45.00   4.35  2.59  0.45  168.43  277.77
# 19  2018-09-07T01:07:18.200Z  85.81  33.78   3.80  1.59  0.38   47.95  308.40
# 20  2018-09-07T01:07:18.200Z  82.59  21.23   6.28  3.37  0.62  259.30  255.61
# 21  2018-09-07T01:07:18.200Z  69.45  31.04   2.92  3.47  0.29   77.12  325.16
# 22  2018-09-07T01:07:18.200Z  82.02  34.59   6.23  1.27  0.63  259.59  273.44
# 23  2018-09-07T01:07:18.200Z  85.81  18.37   3.53  0.60  0.35   26.69  218.06
# 24  2018-09-07T01:07:18.200Z  80.46  45.07   2.59  6.70  0.28  145.59  309.96
# 25  2018-09-07T01:07:18.200Z  84.46  38.77   5.87  4.26  0.57  306.15  323.06
# 26  2018-09-07T01:07:18.200Z  96.39  26.85   0.91  1.32  0.08  343.41  327.84
# 27  2018-09-07T01:07:18.200Z  93.64  27.66   3.94  2.55  0.39  288.35  336.00
# 28  2018-09-07T01:07:18.299Z  95.70  29.37  23.01  4.76  2.76     NaN     NaN
# 29  2018-09-07T01:07:18.299Z  89.02  17.13   7.04  1.78  0.70  169.07  204.02
#
#            event      nflId  ... passResult  offensePlayResult playResult  \
# 0   pass_forward      310.0  ...          C                 10         10
# 1   pass_forward        NaN  ...          C                 10         10
# 2   pass_forward  2559033.0  ...          C                 10         10
# 3   pass_forward  2558175.0  ...          C                 10         10
# 4   pass_forward  2555415.0  ...          C                 10         10
# 5   pass_forward  2552689.0  ...          C                 10         10
# 6   pass_forward  2552315.0  ...          C                 10         10
# 7   pass_forward  2555383.0  ...          C                 10         10
# 8   pass_forward  2534832.0  ...          C                 10         10
# 9   pass_forward  2533040.0  ...          C                 10         10
# 10  pass_forward  2495613.0  ...          C                 10         10
# 11  pass_forward  2495454.0  ...          C                 10         10
# 12  pass_forward    79848.0  ...          C                 10         10
# 13  pass_forward  2543583.0  ...          C                 10         10
# 14          None  2552689.0  ...          C                 10         10
# 15          None        NaN  ...          C                 10         10
# 16          None  2559033.0  ...          C                 10         10
# 17          None  2558175.0  ...          C                 10         10
# 18          None  2555383.0  ...          C                 10         10
# 19          None  2552315.0  ...          C                 10         10
# 20          None  2555415.0  ...          C                 10         10
# 21          None  2534832.0  ...          C                 10         10
# 22          None  2533040.0  ...          C                 10         10
# 23          None  2495613.0  ...          C                 10         10
# 24          None  2495454.0  ...          C                 10         10
# 25          None    79848.0  ...          C                 10         10
# 26          None      310.0  ...          C                 10         10
# 27          None  2543583.0  ...          C                 10         10
# 28          None        NaN  ...          C                 10         10
# 29          None  2559033.0  ...          C                 10         10
#
#          epa isDefensivePI    gameDate  gameTimeEastern homeTeamAbbr  \
# 0   0.261827         False  09/06/2018         20:20:00          PHI
# 1   0.261827         False  09/06/2018         20:20:00          PHI
# 2   0.261827         False  09/06/2018         20:20:00          PHI
# 3   0.261827         False  09/06/2018         20:20:00          PHI
# 4   0.261827         False  09/06/2018         20:20:00          PHI
# 5   0.261827         False  09/06/2018         20:20:00          PHI
# 6   0.261827         False  09/06/2018         20:20:00          PHI
# 7   0.261827         False  09/06/2018         20:20:00          PHI
# 8   0.261827         False  09/06/2018         20:20:00          PHI
# 9   0.261827         False  09/06/2018         20:20:00          PHI
# 10  0.261827         False  09/06/2018         20:20:00          PHI
# 11  0.261827         False  09/06/2018         20:20:00          PHI
# 12  0.261827         False  09/06/2018         20:20:00          PHI
# 13  0.261827         False  09/06/2018         20:20:00          PHI
# 14  0.261827         False  09/06/2018         20:20:00          PHI
# 15  0.261827         False  09/06/2018         20:20:00          PHI
# 16  0.261827         False  09/06/2018         20:20:00          PHI
# 17  0.261827         False  09/06/2018         20:20:00          PHI
# 18  0.261827         False  09/06/2018         20:20:00          PHI
# 19  0.261827         False  09/06/2018         20:20:00          PHI
# 20  0.261827         False  09/06/2018         20:20:00          PHI
# 21  0.261827         False  09/06/2018         20:20:00          PHI
# 22  0.261827         False  09/06/2018         20:20:00          PHI
# 23  0.261827         False  09/06/2018         20:20:00          PHI
# 24  0.261827         False  09/06/2018         20:20:00          PHI
# 25  0.261827         False  09/06/2018         20:20:00          PHI
# 26  0.261827         False  09/06/2018         20:20:00          PHI
# 27  0.261827         False  09/06/2018         20:20:00          PHI
# 28  0.261827         False  09/06/2018         20:20:00          PHI
# 29  0.261827         False  09/06/2018         20:20:00          PHI
#
#    visitorTeamAbbr week
# 0              ATL    1
# 1              ATL    1
# 2              ATL    1
# 3              ATL    1
# 4              ATL    1
# 5              ATL    1
# 6              ATL    1
# 7              ATL    1
# 8              ATL    1
# 9              ATL    1
# 10             ATL    1
# 11             ATL    1
# 12             ATL    1
# 13             ATL    1
# 14             ATL    1
# 15             ATL    1
# 16             ATL    1
# 17             ATL    1
# 18             ATL    1
# 19             ATL    1
# 20             ATL    1
# 21             ATL    1
# 22             ATL    1
# 23             ATL    1
# 24             ATL    1
# 25             ATL    1
# 26             ATL    1
# 27             ATL    1
# 28             ATL    1
# 29             ATL    1
#
# [30 rows x 49 columns]

# %%
m_grouped = df_cd.groupby(['gameId', 'playId'])

# %%
instances_threshold = 10
dpi_dfs = []
non_dpi_dfs =  []
for i, group_data in enumerate(m_grouped):
    name, group = group_data
    game_id, play_id = name
    
    # exit condition
    if (len(dpi_dfs) >= instances_threshold) and (len(non_dpi_dfs) >= instances_threshold):
        break
        
    is_dpi = (group.isDefensivePI).all()
    
    if is_dpi and (len(dpi_dfs) < instances_threshold):
        dpi_dfs.append((game_id, play_id))
        continue
        
    if not is_dpi and (len(non_dpi_dfs) < instances_threshold):
        non_dpi_dfs.append((game_id, play_id))
        
print(f'Dpi shape {np.shape(dpi_dfs)}, non dpi shape {np.shape(non_dpi_dfs)}')
# Out:
# Dpi shape (10, 2), non dpi shape (10, 2)

# %%
for dpi_play in dpi_dfs:
    dpi_slice = df_cd[(df_cd.gameId == dpi_play[0]) & (df_cd.playId == dpi_play[1])]
    fig = animated_slice(dpi_slice)
    fig.show()
# Out:
# <div>                            <div id="693757ef-0b9b-415b-b203-c6acaa11437b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("693757ef-0b9b-415b-b203-c6acaa11437b")) {                    Plotly.newPlot(                        "693757ef-0b9b-415b-b203-c6acaa11437b",                        [{"customdata": [["Nick Foles", 9.0, 1.72, 3.23, 0.19, 305.22, 174.93, "left"], ["Zach Ertz", 86.0, 6.61, 0.41, 0.66, 194.12, 197.85, "left"], ["Markus Wheaton", 80.0, 7.46, 0.45, 0.75, 163.06, 189.0, "left"], ["Mike Wallace", 14.0, 4.26, 5.15, 0.41, 208.58, 206.32, "left"], ["DeAndre Carter", 16.0, 6.06, 1.03, 0.61, 268.17, 250.26, "left"]], "hovertemplate": "team=home<br>time=2018-09-07T01:53:24.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Nick Foles", "Zach Ertz", "Markus Wheaton", "Mike Wallace", "DeAndre Carter"], "legendgroup": "home", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["QB", "TE", "WR", "WR", "WR"], "textposition": "top center", "type": "scatter", "x": [37.13, 21.75, 24.27, 22.14, 19.35], "xaxis": "x", "y": [21.45, 8.62, 21.17, 47.46, 30.06], "yaxis": "y"}, {"customdata": [["Robert Alford", 23.0, 7.49, 1.12, 0.74, 139.08, 172.88, "left"], ["Deion Jones", 45.0, 4.49, 2.39, 0.44, 127.15, 174.37, "left"], ["Keanu Neal", 22.0, 6.23, 1.72, 0.63, 118.48, 201.84, "left"], ["Vic Beasley", 44.0, 4.39, 0.44, 0.44, 101.21, 210.77, "left"], ["De'Vondre Campbell", 59.0, 5.09, 4.24, 0.49, 186.53, 132.08, "left"], ["Ricardo Allen", 37.0, 5.97, 0.89, 0.6, 134.73, 193.39, "left"], ["Desmond Trufant", 21.0, 2.82, 6.77, 0.28, 130.3, 229.12, "left"], ["Brian Poole", 34.0, 6.74, 1.04, 0.68, 153.93, 250.0, "left"]], "hovertemplate": "team=away<br>time=2018-09-07T01:53:24.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Robert Alford", "Deion Jones", "Keanu Neal", "Vic Beasley", "De'Vondre Campbell", "Ricardo Allen", "Desmond Trufant", "Brian Poole"], "legendgroup": "away", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["CB", "MLB", "FS", "OLB", "OLB", "SS", "CB", "CB"], "textposition": "top center", "type": "scatter", "x": [21.93, 29.37, 20.78, 23.49, 37.47, 7.57, 20.48, 18.68], "xaxis": "x", "y": [22.76, 21.83, 9.51, 9.62, 25.89, 19.78, 47.65, 30.59], "yaxis": "y"}, {"customdata": [["Football", null, 1.56, 3.07, 0.15, null, null, "left"]], "hovertemplate": "team=football<br>time=2018-09-07T01:53:24.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [36.89], "xaxis": "x", "y": [21.58], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgree ...
# <div>                            <div id="f8ac05e9-3159-4bbc-968d-4e2a2e83a170" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8ac05e9-3159-4bbc-968d-4e2a2e83a170")) {                    Plotly.newPlot(                        "f8ac05e9-3159-4bbc-968d-4e2a2e83a170",                        [{"customdata": [["Matt Milano", 58.0, 1.45, 3.69, 0.13, 278.46, 19.57, "right"], ["Micah Hyde", 23.0, 3.53, 2.54, 0.35, 307.64, 67.36, "right"], ["Tre'Davious White", 27.0, 7.78, 1.71, 0.78, 92.15, 97.99, "right"], ["Jordan Poyer", 21.0, 5.74, 2.75, 0.57, 310.31, 59.99, "right"], ["Phillip Gaines", 28.0, 1.13, 2.14, 0.1, 219.59, 265.88, "right"], ["Tremaine Edmunds", 49.0, 1.94, 2.98, 0.19, 296.72, 1.36, "right"], ["Lorenzo Alexander", 57.0, 3.51, 2.11, 0.34, 65.79, 258.98, "right"], ["Taron Johnson", 24.0, 7.79, 1.26, 0.78, 54.2, 52.66, "right"]], "hovertemplate": "team=away<br>time=2018-09-09T17:32:27.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Matt Milano", "Micah Hyde", "Tre'Davious White", "Jordan Poyer", "Phillip Gaines", "Tremaine Edmunds", "Lorenzo Alexander", "Taron Johnson"], "legendgroup": "away", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["OLB", "SS", "CB", "FS", "CB", "LB", "OLB", "CB"], "textposition": "top center", "type": "scatter", "x": [54.92, 60.34, 64.26, 71.89, 58.95, 54.11, 38.44, 60.09], "xaxis": "x", "y": [25.95, 33.26, 13.64, 20.14, 44.16, 6.23, 21.88, 25.25], "yaxis": "y"}, {"customdata": [["John Brown", 13.0, 8.34, 2.96, 0.84, 53.65, 99.06, "right"], ["Willie Snead", 83.0, 7.81, 0.84, 0.78, 1.47, 55.39, "right"], ["Javorius Allen", 37.0, 0.73, 1.39, 0.08, 209.41, 324.4, "right"], ["Nick Boyle", 86.0, 1.72, 1.83, 0.17, 302.89, 349.26, "right"], ["Michael Crabtree", 15.0, 5.84, 1.67, 0.59, 242.93, 176.37, "right"]], "hovertemplate": "team=home<br>time=2018-09-09T17:32:27.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["John Brown", "Willie Snead", "Javorius Allen", "Nick Boyle", "Michael Crabtree"], "legendgroup": "home", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["WR", "WR", "RB", "TE", "WR"], "textposition": "top center", "type": "scatter", "x": [65.43, 61.15, 54.76, 53.31, 47.36], "xaxis": "x", "y": [13.24, 26.23, 45.11, 6.03, 17.88], "yaxis": "y"}, {"customdata": [["Football", null, 0.97, 2.37, 0.1, null, null, "right"]], "hovertemplate": "team=football<br>time=2018-09-09T17:32:27.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [36.79], "xaxis": "x", "y": [24.2], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "pap ...
# <div>                            <div id="f0e02789-5fbb-48cd-8390-c20e92d3667d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0e02789-5fbb-48cd-8390-c20e92d3667d")) {                    Plotly.newPlot(                        "f0e02789-5fbb-48cd-8390-c20e92d3667d",                        [{"customdata": [["C.J. Mosley", 57.0, 2.93, 0.49, 0.29, 259.3, 159.21, "right"], ["Eric Weddle", 32.0, 4.75, 1.15, 0.48, 299.33, 56.11, "right"], ["Tavon Young", 25.0, 4.27, 0.91, 0.43, 260.18, 123.11, "right"], ["Matt Judon", 99.0, 2.88, 5.8, 0.32, 171.37, 245.92, "right"], ["Tim Williams", 56.0, 1.93, 2.15, 0.2, 342.64, 294.19, "right"], ["Tony Jefferson", 23.0, 2.37, 1.33, 0.23, 241.01, 118.74, "right"], ["Kenny Young", 40.0, 1.65, 2.08, 0.16, 264.57, 91.25, "right"], ["Marlon Humphrey", 29.0, 6.55, 2.2, 0.64, 152.49, 111.64, "right"]], "hovertemplate": "team=home<br>time=2018-09-09T19:30:26.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["C.J. Mosley", "Eric Weddle", "Tavon Young", "Matt Judon", "Tim Williams", "Tony Jefferson", "Kenny Young", "Marlon Humphrey"], "legendgroup": "home", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["ILB", "FS", "CB", "OLB", "OLB", "SS", "LB", "CB"], "textposition": "top center", "type": "scatter", "x": [92.85, 107.53, 95.13, 79.82, 81.43, 101.67, 93.56, 93.6], "xaxis": "x", "y": [22.29, 22.04, 14.81, 33.82, 26.21, 34.21, 34.73, 8.81], "yaxis": "y"}, {"customdata": [["Kelvin Benjamin", 13.0, 7.35, 0.28, 0.73, 78.09, 63.24, "right"], ["Marcus Murphy", 45.0, 5.08, 2.17, 0.5, 108.89, 93.31, "right"], ["Jeremy Kerley", 10.0, 6.96, 1.92, 0.69, 103.74, 109.31, "right"], ["Zay Jones", 11.0, 7.34, 2.68, 0.73, 98.71, 113.72, "right"], ["Charles Clay", 85.0, 4.63, 3.21, 0.47, 119.0, 78.93, "right"], ["Josh Allen", 17.0, 0.45, 3.37, 0.04, 128.31, 24.58, "right"]], "hovertemplate": "team=away<br>time=2018-09-09T19:30:26.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Kelvin Benjamin", "Marcus Murphy", "Jeremy Kerley", "Zay Jones", "Charles Clay", "Josh Allen"], "legendgroup": "away", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["WR", "RB", "WR", "WR", "TE", "QB"], "textposition": "top center", "type": "scatter", "x": [92.75, 85.13, 91.95, 92.39, 91.9, 79.04], "xaxis": "x", "y": [46.91, 31.68, 14.24, 7.05, 23.22, 30.03], "yaxis": "y"}, {"customdata": [["Football", null, 0.09, 1.44, 0.0, null, null, "right"]], "hovertemplate": "team=football<br>time=2018-09-09T19:30:26.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [79.12], "xaxis": "x", "y": [29.87], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": ...
# <div>                            <div id="238f8bd5-cefd-47f3-82a0-2560bf802b07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("238f8bd5-cefd-47f3-82a0-2560bf802b07")) {                    Plotly.newPlot(                        "238f8bd5-cefd-47f3-82a0-2560bf802b07",                        [{"customdata": [["T.J. Watt", 90.0, 5.55, 1.96, 0.53, 308.55, 305.81, "right"], ["Jon Bostic", 51.0, 4.2, 2.17, 0.41, 105.17, 246.38, "right"], ["Bud Dupree", 48.0, 4.22, 2.85, 0.42, 210.61, 258.79, "right"], ["Vince Williams", 98.0, 4.13, 1.64, 0.42, 273.45, 233.25, "right"], ["Terrell Edmunds", 34.0, 4.93, 0.78, 0.49, 321.77, 30.15, "right"], ["Artie Burns", 25.0, 7.42, 0.88, 0.92, 112.3, 129.43, "right"], ["Sean Davis", 21.0, 4.53, 1.91, 0.46, 253.56, 112.13, "right"]], "hovertemplate": "team=away<br>time=2018-09-09T19:33:24.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["T.J. Watt", "Jon Bostic", "Bud Dupree", "Vince Williams", "Terrell Edmunds", "Artie Burns", "Sean Davis"], "legendgroup": "away", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["OLB", "ILB", "OLB", "ILB", "DB", "CB", "SS"], "textposition": "top center", "type": "scatter", "x": [15.85, 21.35, 17.84, 20.41, 28.25, 27.03, 38.63], "xaxis": "x", "y": [19.88, 22.61, 30.04, 23.34, 22.63, 6.55, 23.23], "yaxis": "y"}, {"customdata": [["Orson Charles", 82.0, 2.11, 3.7, 0.21, 79.83, 156.18, "right"], ["David Njoku", 85.0, 4.81, 1.08, 0.48, 56.14, 53.72, "right"], ["Tyrod Taylor", 5.0, 1.8, 2.75, 0.19, 90.61, 272.4, "right"], ["Darren Fells", 88.0, 6.17, 0.83, 0.61, 66.15, 54.17, "right"], ["Carlos Hyde", 34.0, 1.02, 0.68, 0.11, 130.37, 178.47, "right"], ["Josh Gordon", 12.0, 6.46, 1.38, 0.64, 112.93, 129.5, "right"]], "hovertemplate": "team=home<br>time=2018-09-09T19:33:24.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Orson Charles", "David Njoku", "Tyrod Taylor", "Darren Fells", "Carlos Hyde", "Josh Gordon"], "legendgroup": "home", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["TE", "TE", "QB", "TE", "RB", "WR"], "textposition": "top center", "type": "scatter", "x": [20.3, 25.51, 15.82, 26.19, 16.73, 25.4], "xaxis": "x", "y": [24.67, 31.78, 23.9, 23.33, 22.86, 6.08], "yaxis": "y"}, {"customdata": [["Football", null, 2.32, 2.79, 0.24, null, null, "right"]], "hovertemplate": "team=football<br>time=2018-09-09T19:33:24.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [15.4], "xaxis": "x", "y": [23.48], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgreen", "plot_bgcolor":  ...
# <div>                            <div id="0218c364-34fe-49b0-8cb3-30c9cccf0524" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0218c364-34fe-49b0-8cb3-30c9cccf0524")) {                    Plotly.newPlot(                        "0218c364-34fe-49b0-8cb3-30c9cccf0524",                        [{"customdata": [["Quincy Wilson", 31.0, 5.02, 2.2, 0.49, 119.9, 245.35, "left"], ["Malik Hooker", 29.0, 4.47, 1.06, 0.44, 68.07, 246.3, "left"], ["Nate Hairston", 27.0, 5.37, 2.27, 0.52, 154.34, 273.57, "left"], ["Kenny Moore", 23.0, 4.15, 1.91, 0.41, 105.67, 314.26, "left"], ["Clayton Geathers", 26.0, 3.85, 1.98, 0.37, 60.41, 226.04, "left"], ["Darius Leonard", 53.0, 3.97, 1.42, 0.39, 88.18, 253.22, "left"], ["Skai Moore", 55.0, 3.65, 1.92, 0.35, 44.34, 292.21, "left"]], "hovertemplate": "team=home<br>time=2018-09-09T18:12:38.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Quincy Wilson", "Malik Hooker", "Nate Hairston", "Kenny Moore", "Clayton Geathers", "Darius Leonard", "Skai Moore"], "legendgroup": "home", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["CB", "FS", "CB", "CB", "FS", "LB", "ILB"], "textposition": "top center", "type": "scatter", "x": [43.56, 31.78, 37.73, 42.67, 39.38, 42.16, 42.5], "xaxis": "x", "y": [8.65, 31.01, 45.16, 36.65, 17.47, 24.33, 30.46], "yaxis": "y"}, {"customdata": [["Joe Mixon", 28.0, 5.64, 4.05, 0.56, 271.65, 310.7, "left"], ["John Ross", 15.0, 7.61, 1.16, 0.76, 330.01, 277.38, "left"], ["Tyler Eifert", 85.0, 2.1, 2.91, 0.2, 208.52, 204.71, "left"], ["A.J. Green", 18.0, 7.09, 3.2, 0.7, 258.64, 241.99, "left"], ["Tyler Boyd", 83.0, 7.31, 1.35, 0.72, 271.26, 275.76, "left"]], "hovertemplate": "team=away<br>time=2018-09-09T18:12:38.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Joe Mixon", "John Ross", "Tyler Eifert", "A.J. Green", "Tyler Boyd"], "legendgroup": "away", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["HB", "WR", "TE", "WR", "WR"], "textposition": "top center", "type": "scatter", "x": [51.57, 43.42, 51.07, 44.98, 44.19], "xaxis": "x", "y": [30.7, 44.14, 27.62, 8.19, 34.79], "yaxis": "y"}, {"customdata": [["Football", null, 0.99, 2.68, 0.12, null, null, "left"]], "hovertemplate": "team=football<br>time=2018-09-09T18:12:38.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [56.58], "xaxis": "x", "y": [23.74], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgreen", "plot_bgcolor": "darkgreen", "sliders": [{"active": 0, "currentvalue": {"prefix": "time="}, "len": 0.9, "pad": {"b": 10, "t": 6 ...
# <div>                            <div id="1b26fefc-5ec8-4b52-9683-8c1f325190ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b26fefc-5ec8-4b52-9683-8c1f325190ba")) {                    Plotly.newPlot(                        "1b26fefc-5ec8-4b52-9683-8c1f325190ba",                        [{"customdata": [["Tyler Eifert", 85.0, 5.95, 2.71, 0.6, 292.13, 281.44, "left"], ["Giovani Bernard", 25.0, 4.86, 1.75, 0.48, 222.96, 164.41, "left"], ["John Ross", 15.0, 7.94, 1.2, 0.78, 324.22, 273.4, "left"], ["Tyler Boyd", 83.0, 6.57, 2.19, 0.65, 204.19, 215.05, "left"], ["A.J. Green", 18.0, 6.96, 1.33, 0.69, 262.02, 271.73, "left"]], "hovertemplate": "team=away<br>time=2018-09-09T19:23:39.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Tyler Eifert", "Giovani Bernard", "John Ross", "Tyler Boyd", "A.J. Green"], "legendgroup": "away", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["TE", "HB", "WR", "WR", "WR"], "textposition": "top center", "type": "scatter", "x": [52.26, 64.2, 52.27, 55.81, 52.84], "xaxis": "x", "y": [30.6, 18.6, 42.03, 29.44, 11.9], "yaxis": "y"}, {"customdata": [["Clayton Geathers", 26.0, 3.01, 0.98, 0.3, 108.68, 280.46, "left"], ["Matthias Farley", 41.0, 1.78, 1.22, 0.18, 92.39, 98.81, "left"], ["Quincy Wilson", 31.0, 2.94, 0.73, 0.29, 49.69, 264.24, "left"], ["Malik Hooker", 29.0, 5.33, 1.29, 0.53, 137.82, 246.59, "left"], ["Nate Hairston", 27.0, 4.38, 0.93, 0.43, 149.83, 283.3, "left"], ["Kenny Moore", 23.0, 5.76, 2.94, 0.56, 185.54, 203.08, "left"], ["Darius Leonard", 53.0, 1.65, 4.26, 0.17, 110.16, 298.51, "left"]], "hovertemplate": "team=home<br>time=2018-09-09T19:23:39.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Clayton Geathers", "Matthias Farley", "Quincy Wilson", "Malik Hooker", "Nate Hairston", "Kenny Moore", "Darius Leonard"], "legendgroup": "home", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["FS", "SS", "CB", "FS", "CB", "CB", "LB"], "textposition": "top center", "type": "scatter", "x": [49.73, 46.6, 46.8, 38.41, 45.93, 54.65, 51.61], "xaxis": "x", "y": [30.75, 16.44, 9.38, 28.99, 42.62, 30.8, 26.04], "yaxis": "y"}, {"customdata": [["Football", null, 0.99, 2.05, 0.1, null, null, "left"]], "hovertemplate": "team=football<br>time=2018-09-09T19:23:39.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [65.94], "xaxis": "x", "y": [24.55], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgreen", "plot_bgcolor": "darkgreen", "sliders": [{"active": 0, "currentvalue": {"prefix": "time="}, "len": 0.9, "pa ...
# <div>                            <div id="6c12ca9b-697f-4d54-940e-26ecf5dcdf29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c12ca9b-697f-4d54-940e-26ecf5dcdf29")) {                    Plotly.newPlot(                        "6c12ca9b-697f-4d54-940e-26ecf5dcdf29",                        [{"customdata": [["Tom Brady", 12.0, 1.03, 1.86, 0.1, 150.51, 334.45, "right"], ["Chris Hogan", 15.0, 7.55, 3.44, 0.75, 12.45, 32.72, "right"], ["Rex Burkhead", 34.0, 4.4, 1.51, 0.45, 88.41, 98.8, "right"], ["Phillip Dorsett", 13.0, 7.11, 2.73, 0.72, 52.0, 67.54, "right"], ["James White", 28.0, 6.63, 3.43, 0.66, 343.55, 21.05, "right"], ["Rob Gronkowski", 87.0, 5.65, 3.12, 0.57, 56.58, 70.47, "right"]], "hovertemplate": "team=home<br>time=2018-09-09T17:44:12.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Tom Brady", "Chris Hogan", "Rex Burkhead", "Phillip Dorsett", "James White", "Rob Gronkowski"], "legendgroup": "home", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["QB", "WR", "RB", "WR", "RB", "TE"], "textposition": "top center", "type": "scatter", "x": [41.39, 59.44, 51.85, 61.1, 52.54, 59.26], "xaxis": "x", "y": [30.7, 25.22, 20.98, 13.62, 41.69, 35.56], "yaxis": "y"}, {"customdata": [["Dylan Cole", 51.0, 5.64, 1.39, 0.56, 296.47, 0.78, "right"], ["Aaron Colvin", 22.0, 6.07, 3.31, 0.6, 338.92, 12.86, "right"], ["Tyrann Mathieu", 32.0, 5.25, 1.18, 0.53, 299.58, 69.74, "right"], ["Johnathan Joseph", 24.0, 2.25, 3.04, 0.22, 270.98, 64.38, "right"], ["Benardrick McKinney", 55.0, 2.18, 4.19, 0.21, 287.28, 48.11, "right"], ["Kevin Johnson", 30.0, 5.21, 0.68, 0.52, 139.76, 68.04, "right"]], "hovertemplate": "team=away<br>time=2018-09-09T17:44:12.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Dylan Cole", "Aaron Colvin", "Tyrann Mathieu", "Johnathan Joseph", "Benardrick McKinney", "Kevin Johnson"], "legendgroup": "away", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["ILB", "CB", "FS", "CB", "ILB", "CB"], "textposition": "top center", "type": "scatter", "x": [53.95, 62.59, 70.43, 60.88, 56.43, 65.45], "xaxis": "x", "y": [41.22, 23.97, 26.69, 35.62, 22.11, 12.32], "yaxis": "y"}, {"customdata": [["Football", null, 1.12, 2.49, 0.08, null, null, "right"]], "hovertemplate": "team=football<br>time=2018-09-09T17:44:12.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [41.71], "xaxis": "x", "y": [29.84], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgreen", "plot_bgcolor": "darkgreen", "sliders": [{"active": 0, "currentvalue": {"prefix": "tim ...
# <div>                            <div id="0f8a8407-3a3b-41a1-a40e-a155b01286d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f8a8407-3a3b-41a1-a40e-a155b01286d4")) {                    Plotly.newPlot(                        "0f8a8407-3a3b-41a1-a40e-a155b01286d4",                        [{"customdata": [["Jacquizz Rodgers", 32.0, 5.02, 3.76, 0.49, 51.78, 82.92, "right"], ["Mike Evans", 13.0, 7.33, 1.66, 0.74, 76.9, 80.49, "right"], ["Cameron Brate", 84.0, 5.43, 2.39, 0.54, 24.02, 33.42, "right"], ["Adam Humphries", 10.0, 6.21, 3.45, 0.62, 175.52, 142.65, "right"], ["Ryan Fitzpatrick", 14.0, 0.44, 4.79, 0.05, 138.23, 160.88, "right"]], "hovertemplate": "team=away<br>time=2018-09-09T19:30:55.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Jacquizz Rodgers", "Mike Evans", "Cameron Brate", "Adam Humphries", "Ryan Fitzpatrick"], "legendgroup": "away", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["RB", "WR", "TE", "WR", "QB"], "textposition": "top center", "type": "scatter", "x": [57.3, 68.09, 59.24, 63.22, 49.26], "xaxis": "x", "y": [18.53, 13.37, 32.35, 30.04, 22.55], "yaxis": "y"}, {"customdata": [["Demario Davis", 56.0, 0.53, 4.0, 0.07, 281.45, 144.56, "right"], ["Patrick Robinson", 21.0, 2.98, 0.98, 0.29, 242.42, 5.73, "right"], ["Ken Crawley", 20.0, 3.67, 1.07, 0.37, 182.49, 82.43, "right"], ["Marshon Lattimore", 23.0, 7.86, 0.69, 0.78, 33.09, 72.09, "right"], ["Marcus Williams", 43.0, 3.23, 0.7, 0.32, 251.28, 85.75, "right"], ["Manti Te'o", 51.0, 2.73, 2.6, 0.28, 259.2, 78.14, "right"], ["Kurt Coleman", 29.0, 2.3, 3.96, 0.2, 310.71, 335.2, "right"]], "hovertemplate": "team=home<br>time=2018-09-09T19:30:55.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Demario Davis", "Patrick Robinson", "Ken Crawley", "Marshon Lattimore", "Marcus Williams", "Manti Te'o", "Kurt Coleman"], "legendgroup": "home", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["ILB", "CB", "CB", "CB", "FS", "MLB", "SS"], "textposition": "top center", "type": "scatter", "x": [64.82, 63.24, 72.83, 68.05, 77.93, 68.8, 71.58], "xaxis": "x", "y": [16.26, 36.53, 43.53, 11.72, 33.29, 30.54, 19.91], "yaxis": "y"}, {"customdata": [["Football", null, 0.71, 3.46, 0.12, null, null, "right"]], "hovertemplate": "team=football<br>time=2018-09-09T19:30:55.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [49.32], "xaxis": "x", "y": [22.67], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgreen", "plot_bgcolor": "darkgreen", "sliders": [{"active": 0, "currentvalue": { ...
# <div>                            <div id="9557cfa8-3ad6-4882-a3f3-6dc9fbf8d28a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9557cfa8-3ad6-4882-a3f3-6dc9fbf8d28a")) {                    Plotly.newPlot(                        "9557cfa8-3ad6-4882-a3f3-6dc9fbf8d28a",                        [{"customdata": [["Benjamin Watson", 82.0, 8.04, 1.14, 0.8, 306.99, 242.37, "left"], ["Ted Ginn", 19.0, 8.04, 1.99, 0.81, 312.38, 298.34, "left"], ["Michael Thomas", 13.0, 6.5, 4.54, 0.65, 176.97, 230.21, "left"], ["Alvin Kamara", 41.0, 5.37, 2.53, 0.53, 170.05, 199.41, "left"], ["Josh Hill", 89.0, 6.73, 2.97, 0.68, 236.67, 303.51, "left"], ["Drew Brees", 9.0, 1.62, 0.23, 0.16, 341.74, 299.42, "left"]], "hovertemplate": "team=home<br>time=2018-09-09T19:39:53.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Benjamin Watson", "Ted Ginn", "Michael Thomas", "Alvin Kamara", "Josh Hill", "Drew Brees"], "legendgroup": "home", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["TE", "WR", "WR", "RB", "TE", "QB"], "textposition": "top center", "type": "scatter", "x": [26.28, 16.61, 19.52, 30.02, 26.43, 41.22], "xaxis": "x", "y": [7.95, 15.3, 38.36, 33.05, 47.69, 27.57], "yaxis": "y"}, {"customdata": [["Adarius Taylor", 53.0, 7.55, 3.63, 0.75, 215.32, 241.45, "left"], ["Lavonte David", 54.0, 4.99, 1.92, 0.5, 52.68, 330.58, "left"], ["Kwon Alexander", 58.0, 4.06, 4.51, 0.39, 124.77, 164.44, "left"], ["Vernon Hargreaves", 28.0, 6.83, 2.14, 0.69, 340.52, 301.94, "left"], ["Jordan Whitehead", 31.0, 2.09, 3.16, 0.2, 103.33, 157.62, "left"], ["Carlton Davis", 33.0, 5.94, 1.98, 0.6, 186.45, 305.92, "left"]], "hovertemplate": "team=away<br>time=2018-09-09T19:39:53.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Adarius Taylor", "Lavonte David", "Kwon Alexander", "Vernon Hargreaves", "Jordan Whitehead", "Carlton Davis"], "legendgroup": "away", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["MLB", "OLB", "MLB", "CB", "DB", "CB"], "textposition": "top center", "type": "scatter", "x": [26.53, 26.79, 28.95, 16.19, 14.66, 21.96], "xaxis": "x", "y": [8.83, 44.26, 33.11, 13.97, 36.32, 46.42], "yaxis": "y"}, {"customdata": [["Football", null, 2.21, 1.5, 0.21, null, null, "left"]], "hovertemplate": "team=football<br>time=2018-09-09T19:39:53.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [41.63], "xaxis": "x", "y": [28.05], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgreen", "plot_bgcolor": "darkgreen", "sliders": [{"active": 0, "currentvalue": {"prefix": "time= ...
# <div>                            <div id="1a023e57-d9b2-47b9-9eff-7b1d655c9afd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a023e57-d9b2-47b9-9eff-7b1d655c9afd")) {                    Plotly.newPlot(                        "1a023e57-d9b2-47b9-9eff-7b1d655c9afd",                        [{"customdata": [["Lerentee McCray", 55.0, 3.52, 1.96, 0.35, 209.59, 270.08, "left"], ["A.J. Bouye", 21.0, 1.89, 1.38, 0.18, 64.53, 68.58, "left"], ["Tashaun Gipson", 39.0, 5.01, 1.56, 0.5, 29.25, 331.3, "left"], ["Telvin Smith", 50.0, 2.78, 3.01, 0.3, 148.57, 195.36, "left"], ["Jalen Ramsey", 20.0, 5.74, 2.46, 0.57, 230.33, 281.79, "left"], ["D.J. Hayden", 25.0, 5.27, 1.45, 0.53, 86.68, 190.92, "left"], ["Myles Jack", 44.0, 1.24, 1.14, 0.12, 81.06, 169.35, "left"]], "hovertemplate": "team=away<br>time=2018-09-09T18:12:43.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Lerentee McCray", "A.J. Bouye", "Tashaun Gipson", "Telvin Smith", "Jalen Ramsey", "D.J. Hayden", "Myles Jack"], "legendgroup": "away", "marker": {"color": "#636efa", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "away", "orientation": "v", "showlegend": true, "text": ["OLB", "CB", "FS", "OLB", "CB", "CB", "OLB"], "textposition": "top center", "type": "scatter", "x": [65.59, 44.08, 38.27, 52.03, 45.58, 55.13, 53.5], "xaxis": "x", "y": [30.61, 12.13, 23.96, 34.42, 49.05, 15.99, 25.69], "yaxis": "y"}, {"customdata": [["Sterling Shepard", 87.0, 0.42, 0.34, 0.04, 25.17, 214.28, "left"], ["Odell Beckham", 13.0, 8.94, 0.83, 0.88, 278.68, 278.35, "left"], ["Cody Latimer", 12.0, 1.73, 0.99, 0.18, 28.75, 53.97, "left"], ["Eli Manning", 10.0, 1.45, 2.2, 0.15, 279.56, 273.39, "left"], ["Evan Engram", 88.0, 6.87, 3.87, 0.68, 238.12, 277.7, "left"], ["Saquon Barkley", 26.0, 5.76, 2.22, 0.58, 295.04, 204.46, "left"]], "hovertemplate": "team=home<br>time=2018-09-09T18:12:43.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Sterling Shepard", "Odell Beckham", "Cody Latimer", "Eli Manning", "Evan Engram", "Saquon Barkley"], "legendgroup": "home", "marker": {"color": "#EF553B", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "home", "orientation": "v", "showlegend": true, "text": ["WR", "WR", "WR", "QB", "TE", "RB"], "textposition": "top center", "type": "scatter", "x": [55.69, 42.85, 50.93, 64.26, 51.19, 63.93], "xaxis": "x", "y": [23.73, 40.15, 13.01, 30.02, 50.07, 11.89], "yaxis": "y"}, {"customdata": [["Football", null, 19.87, 3.55, 1.6, null, null, "left"]], "hovertemplate": "team=football<br>time=2018-09-09T18:12:43.000Z<br>x=%{x}<br>y=%{y}<br>position=%{text}<br>displayName=%{customdata[0]}<br>jerseyNumber=%{customdata[1]}<br>s=%{customdata[2]}<br>a=%{customdata[3]}<br>dis=%{customdata[4]}<br>o=%{customdata[5]}<br>dir=%{customdata[6]}<br>playDirection=%{customdata[7]}<extra></extra>", "ids": ["Football"], "legendgroup": "football", "marker": {"color": "#00cc96", "size": 10, "symbol": "circle"}, "mode": "markers+text", "name": "football", "orientation": "v", "showlegend": true, "text": [null], "textposition": "top center", "type": "scatter", "x": [63.52], "xaxis": "x", "y": [30.75], "yaxis": "y"}],                        {"font": {"color": "white"}, "legend": {"title": {"text": "team"}, "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "darkgreen", " ...
